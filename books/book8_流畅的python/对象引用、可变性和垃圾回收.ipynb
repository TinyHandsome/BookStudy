# %%
t1 = (1, 2, [30, 40])

# %%
t2 = (1, 2, [30, 40])

# %%
t1 == t2
# Out:
# True

# %%
id(t1[-1])
# Out:
# 1515625836680

# %%
t1[-1].append(99)

# %%
t1
# Out:
# (1, 2, [30, 40, 99])

# %%
id(t1[-1])
# Out:
# 1515625836680

# %%
t1 == t2
# Out:
# False

# %%
l1 = [3, [55, 44], [7, 8, 9]]

# %%
l2 = list(l1)

# %%
l2
# Out:
# [3, [55, 44], [7, 8, 9]]

# %%
l2 == l1
# Out:
# True

# %%
l2 is l1
# Out:
# False

# %%
a = [10, 20]

# %%
b = [a, 30]

# %%
a.append(b)

# %%
a
# Out:
# [10, 20, [[...], 30]]

# %%
import weakref

# %%
s1 = {1, 2, 3}

# %%
s2 = s1

# %%
def bye():
    print('Gone with the wind...')

# %%
ender = weakref.finalize(s1, bye)

# %%
ender.alive
# Out:
# True

# %%
del s1

# %%
ender.alive
# Out:
# True

# %%
s2 = 'spam'

# %%
ender.alive
# Out:
# True

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-d0257f733e5e> in <module>
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s2
# Out:
# 'spam'

# %%
del(s2)

# %%
del(ender)

# %%
ender
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-56bf7f8d2bbd> in <module>
# ----> 1 ender
#
# NameError: name 'ender' is not defined

# %%
import weakref

# %%
a_set = {0, 1}

# %%
wref = weakref.ref(a_set)

# %%
wref
# Out:
# <weakref at 0x00000160E3697598; to 'set' at 0x00000160E3581BA8>

# %%
wref()
# Out:
# {0, 1}

# %%
a_set = {2, 3, 4}

# %%
wref() is None
# Out:
# False

# %%
wref() is None
# Out:
# False

# %%
class Cheese:
    
    def __init__(self, kind):
        self.kind = kind
    
    def __repr__(self):
        return 'Cheese(%r)' % self.kind

# %%
import weakref

# %%
stock = weakref.WeakValueDictionary()

catalog = [Cheese('Red Leicester'), Cheese('Tilsit'), Cheese('Brie'), Cheese('Parmesan')]

for cheese in catalog:
    stock[cheese.kind] = cheese

# %%
sorted(stock.keys())
# Out:
# ['Brie', 'Parmesan', 'Red Leicester', 'Tilsit']

# %%
del catalog

# %%
sorted(stock.keys())
# Out:
# ['Brie', 'Parmesan', 'Red Leicester', 'Tilsit']

# %%
t1 = (1, 2, 3)

# %%
t2 = tuple(t1)

# %%
t2 is t1
# Out:
# True

# %%
t3 = t1[:]

# %%
t3 is t2
# Out:
# True

# %%
t1 = (1, 2, 3)
t3 = (1, 2, 3)

# %%
t1 is t3
# Out:
# False

# %%
s1 = 'ABC'
s2 = 'ABC'
s2 is s1
# Out:
# True
